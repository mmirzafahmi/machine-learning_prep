# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Product_Exclusive_Classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8000 non-null   int64
#  1   brand              8000 non-null   object
#  2   category           7987 non-null   object
#  3   rating             7905 non-null   float64
#  4   number_of_reviews  7991 non-null   float64
#  5   love               7966 non-null   float64
#  6   price              7992 non-null   float64
#  7   value_price        7983 non-null   float64
#  8   exclusive          8000 non-null   int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 562.6+ KB

# %% [markdown]
# ### Some features has null values such as category, rating, number_of_Reviews, love, price, value_price.

# %%
cats = ['brand', 'category', 'rating', 'exclusive']
nums = ['number_of_reviews', 'love', 'price', 'value_price']

# %%
df['rating'] = df['rating'].astype(str)
df['exclusive'] = df['exclusive'].astype(str)

df[cats].describe()
# Out:
#                      brand category rating exclusive
# count                 8000     7987   8000      8000
# unique                 310      142     11         2
# top     SEPHORA COLLECTION  Perfume    4.5         0
# freq                   492      619   3127      5953

# %%
df['rating'].unique()
# Out:
# array(['5.0', '0.0', '4.5', '3.5', '4.0', 'nan', '2.5', '3.0', '1.0',
#        '2.0', '1.5'], dtype=object)

# %%
df['id'].nunique()
# Out:
# 7951

# %%
df[nums].describe()
# Out:
#        number_of_reviews          love        price  value_price
# count        7991.000000  7.966000e+03  7992.000000  7983.000000
# mean          303.574396  1.756396e+04    49.900935    50.983300
# std           931.724460  4.425339e+04    46.864764    48.473049
# min             0.000000  0.000000e+00     2.000000     2.000000
# 25%            14.000000  2.000000e+03    24.000000    24.000000
# 50%            56.000000  5.500000e+03    35.000000    35.000000
# 75%           231.500000  1.530000e+04    59.000000    60.000000
# max         19000.000000  1.300000e+06   549.000000   549.000000

# %%
df[['brand', 'category']].describe()
# Out:
#                      brand category
# count                 8000     7987
# unique                 310      142
# top     SEPHORA COLLECTION  Perfume
# freq                   492      619

# %%
import seaborn as sns

# %%
sns.boxplot(data=df, x='number_of_reviews')
# Out:
# <Axes: xlabel='number_of_reviews'>

# %%
sns.displot(df['number_of_reviews'])
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df, x='love')
# Out:
# <Axes: xlabel='love'>

# %%
sns.displot(df['love'])
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['price'])
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data=df, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
sns.countplot(data=df, x='rating')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.countplot(data=df, x='exclusive')
# Out:
# <Axes: xlabel='exclusive', ylabel='count'>

# %%
df['brand'].value_counts() # If you want to visualize, filter the feature based on their frequencies.
# Out:
# brand
# SEPHORA COLLECTION    492
# CLINIQUE              211
# TOM FORD              150
# tarte                 143
# Kiehl's Since 1851    122
#                      ...
# Conture                 1
# Cocofloss               1
# Makeup Eraser           1
# Flora + Bast            1
# SHHHOWERCAP             1
# Name: count, Length: 310, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Perfume                  619
# Moisturizers             395
# Face Serums              334
# Value & Gift Sets        241
# Face Wash & Cleansers    225
#                         ...
# Powder Brush               1
# Accessories                1
# Lid Shadow Brush           1
# Spa Tools                  1
# Cleansing Brushes          1
# Name: count, Length: 142, dtype: int64

# %%
sns.histplot(data=df, x='price', hue='exclusive')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
sns.histplot(data=df, x='number_of_reviews', hue='exclusive')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
df['rating'] = df['rating'].astype('float64')
df['exclusive'] = df['exclusive'].astype('Int64')

# %%
df['rating'].fillna(0.5, inplace=True)
# Out:
# C:\Users\muhammad.fahmi\AppData\Local\Temp\ipykernel_42512\182676873.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(0.5, inplace=True)

# %%
import matplotlib.pyplot as plt

heatmap_cols = ['rating', 'price', 'exclusive','number_of_reviews','love']
correlation_matrix = df[heatmap_cols].corr()

plt.figure(figsize = (10,8))
plt.rcParams.update({'font.size': 12})
sns.heatmap(correlation_matrix, cmap = 'viridis', vmin = -1, vmax = 1, center = 0, annot=True, fmt=".2f", square=True, linewidths=.5)
plt.show()

# %%
import matplotlib.pyplot as plt

heatmap_cols = ['rating', 'price', 'exclusive','number_of_reviews','love']
correlation_matrix = df[heatmap_cols].corr(method='spearman')

plt.figure(figsize = (10,8))
plt.rcParams.update({'font.size': 12})
sns.heatmap(correlation_matrix, cmap = 'viridis', vmin = -1, vmax = 1, center = 0, annot=True, fmt=".2f", square=True, linewidths=.5)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8000 non-null   int64
#  1   brand              8000 non-null   object
#  2   category           7987 non-null   object
#  3   rating             8000 non-null   float64
#  4   number_of_reviews  7991 non-null   float64
#  5   love               7966 non-null   float64
#  6   price              7992 non-null   float64
#  7   value_price        7983 non-null   float64
#  8   exclusive          8000 non-null   Int64
# dtypes: Int64(1), float64(5), int64(1), object(2)
# memory usage: 570.4+ KB

# %%
df['number_of_reviews'].fillna(df['number_of_reviews'].median(), inplace=True)
df['love'].fillna(df['love'].median(), inplace=True)
df['price'].fillna(df['price'].median(), inplace=True)
df['value_price'].fillna(df['value_price'].median(), inplace=True)
df['category'].fillna(df['category'].mode(), inplace=True)
# Out:
# C:\Users\muhammad.fahmi\AppData\Local\Temp\ipykernel_42512\1630985848.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['number_of_reviews'].fillna(df['number_of_reviews'].median(), inplace=True)
# C:\Users\muhammad.fahmi\AppData\Local\Temp\ipykernel_42512\1630985848.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.dropna(subset=['category'], inplace=True)

# %%
df.drop_duplicates(subset=['brand', 'category', 'rating', 'price'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6574 entries, 0 to 7999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 6574 non-null   int64
#  1   brand              6574 non-null   object
#  2   category           6574 non-null   object
#  3   rating             6574 non-null   float64
#  4   number_of_reviews  6574 non-null   float64
#  5   love               6574 non-null   float64
#  6   price              6574 non-null   float64
#  7   value_price        6574 non-null   float64
#  8   exclusive          6574 non-null   Int64
# dtypes: Int64(1), float64(5), int64(1), object(2)
# memory usage: 520.0+ KB

# %%
def outlier_handler(df, col):

    """
    Utility function to clean outlier using Tukey Fences Method.
    :param df: Dataframe with outlier (pd.DataFrame)
    :param col: Numerical Feature (String)
    :return: Dataframe without outlier (pd.DataFrame)
    """

    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3-q1

    up_bound = q3 + 1.5*iqr
    low_bound = q1 - 1.5*iqr

    outlier = df[col][(df[col] < low_bound) | (df[col] > up_bound)]

    print(f'Percentage of outliers: {len(outlier)*100/len(df[col]):.2f}%')

    no_outlier = df[(df[col] >= low_bound) & (df[col] <= up_bound)]

    return outlier, no_outlier

# %%
_, no_outlier = outlier_handler(df, 'price')
# Out:
# Percentage of outliers: 7.73%

# %%
sns.boxplot(data=no_outlier, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
_, no_outlier = outlier_handler(no_outlier, 'love')
# Out:
# Percentage of outliers: 11.00%

# %%
sns.boxplot(data=no_outlier, x='love')
# Out:
# <Axes: xlabel='love'>

# %%
sns.histplot(data=no_outlier, x='price')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data=no_outlier, x='love')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='love', ylabel='Count'>

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
no_outlier['love'] = scaler.fit_transform(no_outlier[['love']])
no_outlier['price'] = scaler.fit_transform(no_outlier[['price']])

# %%
sns.histplot(data=no_outlier, x='price')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data=no_outlier, x='love')
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='love', ylabel='Count'>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
no_outlier['rating'] = le.fit_transform(no_outlier[['rating']])
# Out:
# c:\Users\muhammad.fahmi\AppData\Local\miniconda3\envs\sandbox\lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
no_outlier['rating'].unique()
# Out:
# array([10,  0,  9,  8,  1,  7,  6,  5,  4,  2,  3], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

df_final = no_outlier.drop(['brand','category','id', 'value_price', 'number_of_reviews','rating'], axis=1)

X = df_final.drop(['exclusive'], axis=1)
y = df_final['exclusive']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#           love     price
# 7726  7.600902  0.116945
# 5999  9.392662 -0.926214
# 1587  7.377759 -0.317704
# 7907  6.539586  2.420587
# 7599  9.674074 -0.926214
# ...        ...       ...
# 2096  8.160518 -0.882749
# 1210  9.220291 -0.621959
# 3103  9.179881 -1.056609
# 7668  8.536996 -0.708889
# 4113  8.160518 -0.752354
#
# [4319 rows x 2 columns]

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train_resample, y_train_resample = SMOTE().fit_resample(X_train, y_train)

# %%
y_train_resample.value_counts()
# Out:
# exclusive
# 0    3147
# 1    3147
# Name: count, dtype: Int64

# %%
no_outlier['avg_likeliness'] = no_outlier['love']/no_outlier['number_of_reviews'] * 100

# %%
def encode_rating(rating):

    if rating == 4.5:
        return 5.0
    elif rating == 3.5:
        return 4.0
    elif rating == 2.5:
        return 3.0
    elif rating == 1.5:
        return 2.0
    elif rating in [0.5, 0.0]:
        return 1.0

# %%
df['new_rating'] = df['rating'].apply(lambda r: encode_rating(r))

# %%
df['new_rating'].unique()
# Out:
# array([nan,  1.,  5.,  4.,  3.,  2.])

# %%
df['new_rating'].fillna(df['new_rating'].median(), inplace=True)
# Out:
# C:\Users\muhammad.fahmi\AppData\Local\Temp\ipykernel_80748\3471504864.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['new_rating'].fillna(df['new_rating'].median(), inplace=True)

# %%
df['new_rating'].value_counts()
# Out:
# new_rating
# 5.0    5500
# 4.0     882
# 1.0     121
# 3.0      75
# 2.0       7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

heatmap_cols = ['rating', 'price', 'exclusive','number_of_reviews','love', 'avg_likeliness']
correlation_matrix = no_outlier[heatmap_cols].corr(method='spearman')

plt.figure(figsize = (10,8))
plt.rcParams.update({'font.size': 12})
sns.heatmap(correlation_matrix, cmap = 'viridis', vmin = -1, vmax = 1, center = 0, annot=True, fmt=".2f", square=True, linewidths=.5)
plt.show()
